# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rho_i = 917.0
rho_w = 1000.0
g = 9.81

def psi(dbdx = 0, dhdx = 0 ):
    return -rho_w*g*dbdx - rho_i*g*dhdx

# use the basic hydraulic gradient to calculate the effective pressure

def effective_pressure(dbdx = 0, dhdx = 0 ):
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [2], line 17
#      13     plt.ylabel('psi')
#      14     plt.show()
# ---> 17 plot_psi(0.0001, 0.0001)
#
# Cell In [2], line 11, in plot_psi(dbdx, dhdx)
#       9 x = np.linspace(0, 40000, 1000)
#      10 y = psi(dbdx, dhdx)
# ---> 11 plt.plot(x, y)
#      12 plt.xlabel('x')
#      13 plt.ylabel('psi')
#
# File ~/opt/anaconda3/envs/conda_main_env_4/lib/python3.10/site-packages/matplotlib/pyplot.py:2728, in plot(scalex, scaley, data, *args, **kwargs)
#    2726 @_copy_docstring_and_deprecators(Axes.plot)
#    2727 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2728     return gca().plot(
#    2729         *args, scalex=scalex, scaley=scaley,
#    2730         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A_0 = 1.0
Q = 80e3
R = 8.314   # J/mol/K
T = np.arange(250, 273, 1) 
A= A_0*np.exp(-Q/R/T)

fig, ax = plt.subplots()
ax.plot(T, A)
